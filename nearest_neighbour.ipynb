# %%
__author__ = "whackadoodle"

import tensorflow as tf
import numpy as np

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
X_train, Y_train = mnist.train.next_batch(5000)
X_test, Y_test = mnist.test.next_batch(200)


x_train = tf.placeholder("float")
x_test = tf.placeholder("float")

# Obtain the Nearest Neighbour using L1 Distance
# Computing the L1 Distance
distance = tf.reduce_sum(tf.abs(tf.add(x_train, tf.negative(x_test))), reduction_indices=1)

# Get the minimum distance index i.e. the Nearest Neighbour
prediction = tf.arg_min(distance, 0)

# Initializing the variables
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    
    accuracy = 0.

    for i in range(len(X_test)):
        nearest_neighbour = sess.run(prediction, feed_dict={x_train: X_train, x_test: X_test[i]})
        # Get the label associated with the nearest neighbour and compare it with the actual label
        print "Test Prediction = %i " % np.argmax(Y_train[nearest_neighbour]) + " , True Label = %i" % np.argmax(Y_test[i]) 
        
        # Computing the accuracy of the model
        if np.argmax(Y_train[nearest_neighbour]) == np.argmax(Y_test[i]):
            accuracy += 1./len(X_test)
    
    print "Accuracy = " + str(accuracy)
# Out:
# Test Prediction = 7  , True Label = 7
# Test Prediction = 2  , True Label = 2
# Test Prediction = 1  , True Label = 1
# Test Prediction = 0  , True Label = 0
# Test Prediction = 4  , True Label = 4
# Test Prediction = 1  , True Label = 1
# Test Prediction = 4  , True Label = 4
# Test Prediction = 9  , True Label = 9
# Test Prediction = 8  , True Label = 5
# Test Prediction = 9  , True Label = 9
# Test Prediction = 0  , True Label = 0
# Test Prediction = 0  , True Label = 6
# Test Prediction = 9  , True Label = 9
# Test Prediction = 0  , True Label = 0
# Test Prediction = 1  , True Label = 1
# Test Prediction = 5  , True Label = 5
# Test Prediction = 4  , True Label = 9
# Test Prediction = 7  , True Label = 7
# Test Prediction = 3  , True Label = 3
# Test Prediction = 4  , True Label = 4
# Test Prediction = 9  , True Label = 9
# Test Prediction = 6  , True Label = 6
# Test Prediction = 6  , True Label = 6
# Test Prediction = 5  , True Label = 5
# Test Prediction = 4  , True Label = 4
# Test Prediction = 0  , True Label = 0
# Test Prediction = 7  , True Label = 7
# Test Prediction = 4  , True Label = 4
# Test Prediction = 0  , True Label = 0
# Test Prediction = 1  , True Label = 1
# Test Prediction = 3  , True Label = 3
# Test Prediction = 1  , True Label = 1
# Test Prediction = 3  , True Label = 3
# Test Prediction = 4  , True Label = 4
# Test Prediction = 7  , True Label = 7
# Test Prediction = 2  , True Label = 2
# Test Prediction = 7  , True Label = 7
# Test Prediction = 1  , True Label = 1
# Test Prediction = 2  , True Label = 2
# Test Prediction = 1  , True Label = 1
# Test Prediction = 1  , True Label = 1
# Test Prediction = 7  , True Label = 7
# Test Prediction = 4  , True Label = 4
# Test Prediction = 1  , True Label = 2
# Test Prediction = 3  , True Label = 3
# Test Prediction = 5  , True Label = 5
# Test Prediction = 1  , True Label = 1
# Test Prediction = 2  , True Label = 2
# Test Prediction = 4  , True Label = 4
# Test Prediction = 4  , True Label = 4
# Test Prediction = 6  , True Label = 6
# Test Prediction = 3  , True Label = 3
# Test Prediction = 5  , True Label = 5
# Test Prediction = 5  , True Label = 5
# Test Prediction = 6  , True Label = 6
# Test Prediction = 0  , True Label = 0
# Test Prediction = 4  , True Label = 4
# Test Prediction = 1  , True Label = 1
# Test Prediction = 9  , True Label = 9
# Test Prediction = 5  , True Label = 5
# Test Prediction = 7  , True Label = 7
# Test Prediction = 8  , True Label = 8
# Test Prediction = 9  , True Label = 9
# Test Prediction = 3  , True Label = 3
# Test Prediction = 7  , True Label = 7
# Test Prediction = 4  , True Label = 4
# Test Prediction = 6  , True Label = 6
# Test Prediction = 4  , True Label = 4
# Test Prediction = 3  , True Label = 3
# Test Prediction = 0  , True Label = 0
# Test Prediction = 7  , True Label = 7
# Test Prediction = 0  , True Label = 0
# Test Prediction = 2  , True Label = 2
# Test Prediction = 7  , True Label = 9
# Test Prediction = 1  , True Label = 1
# Test Prediction = 7  , True Label = 7
# Test Prediction = 3  , True Label = 3
# Test Prediction = 7  , True Label = 2
# Test Prediction = 9  , True Label = 9
# Test Prediction = 7  , True Label = 7
# Test Prediction = 7  , True Label = 7
# Test Prediction = 6  , True Label = 6
# Test Prediction = 2  , True Label = 2
# Test Prediction = 7  , True Label = 7
# Test Prediction = 8  , True Label = 8
# Test Prediction = 4  , True Label = 4
# Test Prediction = 7  , True Label = 7
# Test Prediction = 3  , True Label = 3
# Test Prediction = 6  , True Label = 6
# Test Prediction = 1  , True Label = 1
# Test Prediction = 3  , True Label = 3
# Test Prediction = 6  , True Label = 6
# Test Prediction = 9  , True Label = 9
# Test Prediction = 3  , True Label = 3
# Test Prediction = 1  , True Label = 1
# Test Prediction = 4  , True Label = 4
# Test Prediction = 1  , True Label = 1
# Test Prediction = 7  , True Label = 7
# Test Prediction = 6  , True Label = 6
# Test Prediction = 9  , True Label = 9
# Test Prediction = 6  , True Label = 6
# Test Prediction = 0  , True Label = 0
# Test Prediction = 5  , True Label = 5
# Test Prediction = 4  , True Label = 4
# Test Prediction = 9  , True Label = 9
# Test Prediction = 9  , True Label = 9
# Test Prediction = 2  , True Label = 2
# Test Prediction = 1  , True Label = 1
# Test Prediction = 9  , True Label = 9
# Test Prediction = 4  , True Label = 4
# Test Prediction = 8  , True Label = 8
# Test Prediction = 7  , True Label = 7
# Test Prediction = 3  , True Label = 3
# Test Prediction = 9  , True Label = 9
# Test Prediction = 7  , True Label = 7
# Test Prediction = 9  , True Label = 4
# Test Prediction = 9  , True Label = 4
# Test Prediction = 4  , True Label = 4
# Test Prediction = 9  , True Label = 9
# Test Prediction = 7  , True Label = 2
# Test Prediction = 5  , True Label = 5
# Test Prediction = 4  , True Label = 4
# Test Prediction = 7  , True Label = 7
# Test Prediction = 6  , True Label = 6
# Test Prediction = 7  , True Label = 7
# Test Prediction = 9  , True Label = 9
# Test Prediction = 0  , True Label = 0
# Test Prediction = 5  , True Label = 5
# Test Prediction = 8  , True Label = 8
# Test Prediction = 5  , True Label = 5
# Test Prediction = 6  , True Label = 6
# Test Prediction = 6  , True Label = 6
# Test Prediction = 5  , True Label = 5
# Test Prediction = 7  , True Label = 7
# Test Prediction = 8  , True Label = 8
# Test Prediction = 1  , True Label = 1
# Test Prediction = 0  , True Label = 0
# Test Prediction = 1  , True Label = 1
# Test Prediction = 6  , True Label = 6
# Test Prediction = 4  , True Label = 4
# Test Prediction = 6  , True Label = 6
# Test Prediction = 7  , True Label = 7
# Test Prediction = 2  , True Label = 3
# Test Prediction = 1  , True Label = 1
# Test Prediction = 7  , True Label = 7
# Test Prediction = 1  , True Label = 1
# Test Prediction = 8  , True Label = 8
# Test Prediction = 2  , True Label = 2
# Test Prediction = 0  , True Label = 0
# Test Prediction = 1  , True Label = 2
# Test Prediction = 9  , True Label = 9
# Test Prediction = 9  , True Label = 9
# Test Prediction = 5  , True Label = 5
# Test Prediction = 5  , True Label = 5
# Test Prediction = 1  , True Label = 1
# Test Prediction = 5  , True Label = 5
# Test Prediction = 6  , True Label = 6
# Test Prediction = 0  , True Label = 0
# Test Prediction = 3  , True Label = 3
# Test Prediction = 4  , True Label = 4
# Test Prediction = 4  , True Label = 4
# Test Prediction = 6  , True Label = 6
# Test Prediction = 5  , True Label = 5
# Test Prediction = 4  , True Label = 4
# Test Prediction = 6  , True Label = 6
# Test Prediction = 5  , True Label = 5
# Test Prediction = 4  , True Label = 4
# Test Prediction = 5  , True Label = 5
# Test Prediction = 1  , True Label = 1
# Test Prediction = 4  , True Label = 4
# Test Prediction = 9  , True Label = 4
# Test Prediction = 7  , True Label = 7
# Test Prediction = 2  , True Label = 2
# Test Prediction = 3  , True Label = 3
# Test Prediction = 2  , True Label = 2
# Test Prediction = 1  , True Label = 7
# Test Prediction = 1  , True Label = 1
# Test Prediction = 8  , True Label = 8
# Test Prediction = 1  , True Label = 1
# Test Prediction = 8  , True Label = 8
# Test Prediction = 1  , True Label = 1
# Test Prediction = 8  , True Label = 8
# Test Prediction = 5  , True Label = 5
# Test Prediction = 0  , True Label = 0
# Test Prediction = 2  , True Label = 8
# Test Prediction = 9  , True Label = 9
# Test Prediction = 2  , True Label = 2
# Test Prediction = 5  , True Label = 5
# Test Prediction = 0  , True Label = 0
# Test Prediction = 1  , True Label = 1
# Test Prediction = 1  , True Label = 1
# Test Prediction = 1  , True Label = 1
# Test Prediction = 0  , True Label = 0
# Test Prediction = 4  , True Label = 9
# Test Prediction = 0  , True Label = 0
# Test Prediction = 1  , True Label = 3
# Test Prediction = 1  , True Label = 1
# Test Prediction = 6  , True Label = 6
# Test Prediction = 4  , True Label = 4
# Test Prediction = 2  , True Label = 2
# Accuracy = 0.92
